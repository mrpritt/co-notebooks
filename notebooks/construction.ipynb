# %% [markdown]
# # Planejamento ótimo para construir uma casa

# %% [markdown]
# Para cada etapa $i$ que tem um pré-requisito $j$ de duração $d_j$ podemos adicionar uma restrição $t_i\geq t_j+d_j$ para garantir que a etapa não inicia antes da etapa que é pré-requisito terminar.

# %%
using JuMP
using GLPK

# %% [markdown]
# Primeiramente vamos criar uma lista de pares de tarefas, e um array de durações. (Notam que os índices em Julia começam em 1.)

# %%
p = [ (0,1), (1,2), (1,3), (3,4), (3,5), (2,6), (4,6), (5,7), (6,7), (2,8), (4,8), (7,9), (8,9) ]
d = [ 0, 2, 1, 3, 2.5, 1.5, 2, 4, 3, 0];

# %% [markdown]
# Com isso podemos formular:

# %%
m = Model(GLPK.Optimizer);

# %%
@variable(m, t[1:10] >= 0)

# %%
@objective(m, Min, t[10])

# %%
@constraint(m, [pr in p], t[pr[2]+1] >= t[pr[1]+1]+d[pr[1]+1])

# %%
print(m)
